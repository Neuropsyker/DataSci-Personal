# %% [markdown]
# Statistics problem set:

# %% [markdown]
# - Q1. Define what a population is
# - Q2. Define what a sample is
# - Q3. Give examples of a population based survey
# - Q4. Give examples of a sample based survey
# - Q5. Give example of qualitative data; of both ordinal and nominal types
# - Q6. How do you calculate the arthimetic mean?
# - Q7. How do you calculate the median?
# - Q8. How do you calculate the mode of a dataset?
# - Q9. Calculate the mean of the following values:

# %%
find_mean = [12, 122, 22, 33, 34, 45, 34, 34, 23, 34, 55, 56, 7, 77, 45, 45, 499, 99, 49, 49, 450]

# %% [markdown]
# Q10. Calculate the median of the following values:

# %%
find_median = [12, 122, 22, 33, 34, 45, 34, 34, 23, 34, 55, 56, 7, 77, 45, 45, 499, 99, 49, 49, 450]

# %% [markdown]
# Q11. Find the mode of the following values:

# %%
find_mode = [12, 122, 22, 33, 34, 45, 34, 34, 23, 34, 55, 56, 7, 77, 45, 45, 499, 99, 49, 49, 450]

# %% [markdown]
# Q12. Create a dataset with a postive skew

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Q13. Create a dataset with a symmetrical distribution

# %% [markdown]
# Q14. Create a dataset with a negative skew

# %% [markdown]
# Q15. You have the income for 11 people in the US, calculate the variance of their income - what does this tell you?

# %%
import numpy as np
Annual_Income = [62000, 64000, 49000,324000, 1264000, 54330, 64000, 51000, 55000, 48000, 53000]
Annual_Income_2 = [i/1000 for i in Annual_Income ]
print(f"annual income: {np.var(Annual_Income)}, annual income / 1000 {np.var(Annual_Income_2)}")
# Out:
# annual income: 121303099578.51239, annual income / 1000 121303.09957851243

# %% [markdown]
# Q16. Define the mean, the variance and the standard deviation of the following data points:

# %%
Annual_income_india = [1999.999, 222234, 222320, 344000, 33329]
Annual_income_russia = [2222, 3350, 2390,3339,3999]

# %% [markdown]
# Q17. Find the covariance of the following data points

# %%
import pandas as pd

df = pd.DataFrame()
df['Writing'] = [341, 383, 611, 713, 814, 536]
df['Reading'] = [255, 566, 300, 125, 111, 165]

# Find the mean of the writing series
# Find the mean of the reading series
# For each pair of values use the covariance numerator code
# Identify if this is a sample or a full dataset

# %%
import numpy as np
cm = np.cov(df['Writing'], df['Reading'], bias=False)
cm[0,1]
# Out:
# -21401.466666666667

# %% [markdown]
# Q18. Review the housing data:
#
# - a. What are the types of data and the levels of measurement of the following variables: Cust ID, Mortgage, Year of sale
# - b. Create a frequency distribution graph representing the price (that is a histogram with the highest possible number of bins - 267). Use data on all apartments and offices, no matter if sold or not.
# - c. Create a histogram which represents the Price variable. Choose interval width (bins) of length $100,000.
# - d. Interpret the results
# - e. Create a scatter plot showing the relationship between Price and Area. Use the data on all properties, no matter if sold or not. Interpret the results.
# - f. Create a frequency distribution table, where you list all the countries from which the company has buyers (country vs number of buyers). Count the absolute frequency, the relative frequency and the cumulative frequency.
# - g. Calculate the mean, median, mode, skewness, variance and standard deviation of Price for all properties, no matter if sold or not.
# - h. Calculate the covariance and correlation coefficient between Price and Area, no matter if the property is sold or not. Is the result in line with the scatter plot?

# %% [markdown]
# Q19. What is the null hypothesis?

# %% [markdown]
# Q20. What is the null hypothesis for the following test scenario?
#
# We believe Boris Johnson's goverment had more cabinet reshuffles than the Sunak goverment.
#
# - _The null hypothesis would be:_
# - _The alternative hypothesis would be:_
