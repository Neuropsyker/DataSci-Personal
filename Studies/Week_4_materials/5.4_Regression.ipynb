# %% [markdown]
# Regression

# %% [markdown]
# Logistic Regression

# %% [markdown]
# What is logistic regression?
#
# Practically, it is used to classify observations into different categories. Hence, its output is discrete in nature. Logistic Regression is also called Logit Regression. It is one of the most simple, straightforward and versatile classification algorithms which is used to solve classification problems.

# %% [markdown]
# Linear logistic regression:
#
# Logistic Regression algorithm works by implementing a linear equation with independent or explanatory variables to predict a response value. For example, we consider the example of number of hours studied and probability of passing the exam. Here, number of hours studied is the explanatory variable and it is denoted by x1. Probability of passing the exam is the response or target variable and it is denoted by z.
#
# If we have one explanatory variable (x1) and one response variable (z), then the linear equation would be given mathematically with the following equation-
#
# $z = β0 + β1x1$

# %% [markdown]
# Here, the coefficients β0 and β1 are the parameters of the model.
#
# If there are multiple explanatory variables, then the above equation can be extended to
#
# $z = β0 + β1x1+ β2x2+……..+ βnxn$

# %% [markdown]
# Here, the coefficients β0, β1, β2 and βn are the parameters of the model.
#
# So, the predicted response value is given by the above equations and is denoted by z.

# %% [markdown]
# ### Sigmoid Function
#
# This predicted response value, denoted by z is then converted into a probability value that lie between 0 and 1. We use the sigmoid function in order to map predicted values to probability values. This sigmoid function then maps any real value into a probability value between 0 and 1.
#
# In machine learning, sigmoid function is used to map predictions to probabilities. The sigmoid function has an S shaped curve. It is also called sigmoid curve.
#
# A Sigmoid function is a special case of the Logistic function. It is given by the following mathematical formula.

# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np 

vals = np.arange(-8,9,1)

# implement the logistic regression equation
function_x = 1/(1 + np.exp(-vals))

# Plot the function
fig, ax = plt.subplots()
plt.plot(vals, function_x)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.axhline(0.5, 'Decision boundary')
plt.title('Sigmoid function');

# If the output of the function is greater than or equal to 0.5 then it falls into class 1
# If the output of the function is less than 0.5 then the class is 0

# %% [markdown]
# The sigmoid function returns a probability value between 0 and 1. This probability value is then mapped to a discrete class which is either “0” or “1”.
#
# In order to map this probability value to a discrete class (pass/fail, yes/no, true/false), we select a threshold value. This threshold value is called Decision boundary.
#
# Above this threshold value, we will map the probability values into class 1 and below which we will map values into class 0.

# %% [markdown]
# ### How we use the logistic regression model
#
# 1. The logistic regression model requires the dependent variable to be binary, multinomial, or ordinal in nature
# 2. Logistic regression requires little of no multicollinearity among the independent variables. It means that the independent variables should not be too highly correlated with each other.
# 3. Logistic regression assumes linearity of independent variables and log odds.
# 4. Logistic regression depends on the sample size and it requires a large sample size to achieve the high accuracy.

# %% [markdown]
# ### Types of Logistic Regression
#
# 1. Binary Logistic Regression - the target variable has 2 possible categories
# 2. Multinomial Logistic Regression - the target variable has 3 or more categories whcih are not in any particular
# 3. Ordinal Logistic Regression - the  target variable has three or more ordinal categories, so there is an intrinsic order involved with the categories
